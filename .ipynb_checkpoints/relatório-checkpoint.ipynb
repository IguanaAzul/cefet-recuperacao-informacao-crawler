# %% [markdown]
# # Relatório
# ## Ramon Griffo e Willian Silva

# %% [markdown]
# ### Imports

# %%
from urllib.parse import urlparse, urljoin, ParseResult
from crawler import PageFetcher, Scheduler
from collections import OrderedDict
from crawler.domain import Domain
import seaborn as sns
from matplotlib import pyplot as plt
import time
import numpy as np
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# ### Arquitetura implementada:
#
# - A partir da lista de sementes, instanciamos uma lista de urls, inicialmente, todas com profundidade 0.
# - Cada thread vai ser uma instância de page fetcher que buscará novas urls para incluir na lista a partir das urls da ainda não buscadas.
# - As funções de coletar são sincronizadas para evitar que duas threads coletem a mesma página simultaneamente.
# - Ao coletar uma url, definimos sua profundidade, que será somada em 1 se for no mesmo domínio onde foi encontrada ou setada como 0 caso contrário.
# - Definimos um limite de páginas coletadas e um máximo de profundidade.

# %% [markdown]
# ### Decisões e desafios:
#
# - Ao invés de retornar o generator usando yield no método discover_links, já checamos e adicionamos a página na lista dentro do próprio método.
# - Muitas vezes o coletor dava erro por existirem muitos links com formatos inesperados como javascript e páginas mal formatadas ou em outras codificações. Decidimos colocar um tratamento de exceções que ignora esses links e páginas e exibe no terminal o erro encontrado.

# %% [markdown]
# ### Sementes Utilizadas

# %%
seeds = ["https://5e.tools/", "https://www.dmsguild.com/", "https://www.dndbeyond.com/", "https://hitpointpress.com/", "https://ghostfiregaming.com/", "https://www.mercadorpg.com.br/"]

# %%
studies = list()
results = list()

# %% [markdown]
# ### Criação dos estudos

# %%
n_threads = list(np.arange(1, 20, step=1)) + list(np.arange(30, 100, step=10))
for n in n_threads:
    studies.append({"n_threads": n})

# %% [markdown]
# ### Execução dos estudos
#
# Para cada estudo, executamos um coletor com limite de 100 páginas e profundidade máxima de 6.
# Cada um dos estudos tem uma diferente quantidade de threads e cada estudo terá seu tempo medido e armazenado.

# %%
for study in tqdm(studies):
    start_time = time.time()
    scheduler = Scheduler("rpg-bot", page_limit=100, depth_limit=6, arr_urls_seeds=[urlparse(seed) for seed in seeds])
    n_threads = study["n_threads"]
    threads = list()
    for t in range(n_threads):
        pf = PageFetcher(scheduler)
        pf.start()
        threads.append(pf)
    for thread in threads:
        thread.join()
    new_time = time.time()
    total_time = new_time - start_time
    print(f"{total_time} segundos = {total_time / 60} minutos")
    results.append({"n_threads": n_threads, "time": total_time})
# Out:
#   0%|                                                                                                                                                                                                                | 0/26 [00:00<?, ?it/s]
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/', params='', query='', fragment=''), 0)
# A url 'https://www.mercadorpg.com.br/' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0xe9 in position 1008: invalid continuation byte
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/DungeonMastersGuild', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/login.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=e2c6ccc1d5f6129259117c1089982d09&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/my_library.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_262/Gamma-World', params='', query='src=DnDClassicsButton', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrucards.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='', fragment='timeline'), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=b4b2ea16407aed7ca298878c727dff2f&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/wishlist.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrucomics.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/hitpointpress', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/shopping_cart.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/shopping_cart.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrufiction.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/i/moments', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=37bcd101f2be8defcc33ebe116f03922&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment='login_box'), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/index.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.wargamevault.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='', fragment='supported_languages'), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=90fa256fd654aae3b4080405c8115564&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment='create_account_box'), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/login.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=id', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.storytellersvault.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/DriveThruRPG', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=msa', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/password_forgotten.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/my_library.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.pathfinderinfinite.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=ca', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=181736421874745&state=5d9b9576c8cf09b6ab3fa7673f254fd4&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.drivethrurpg.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/promo.php', params='', query='&filters=0_0_0_0_0_0_0_0_1000008', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/wishlist.php', params='', query='', fragment=''), 1)
# A url 'https://support.dmsguild.com/hc/en-us/categories/1260801293870-Content-Creator-Questions' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=cs', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=181736421874745&state=74fa183ff207c7d5cfc489b30a8978a5&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.drivethrurpg.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45469_0_0_0_0_0_0_0&src=fid45469', fragment=''), 1)
# A url 'https://docs.google.com/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform?usp=pp_url&entry.1569704748=Dungeon Masters Guild' não foi coletada, a seguinte exceção foi lançada:
# <class 'http.client.InvalidURL'>: URL can't contain control characters. '/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform?usp=pp_url&entry.1569704748=Dungeon Masters Guild' (found at least ' ')
# A url 'https://support.drivethrurpg.com/hc/en-us/articles/209937123-About-DriveThruRPG' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/', params='', query='', fragment='MainContent'), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=da', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment='login_box'), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45680_0_0_0_0_0_0_0&src=fid45680', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruRPG.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=de', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/r.php', params='', query='locale=pt_BR', fragment=''), 1)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45470_0_0_0_0_0_0_0&src=fid45470', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment='create_account_box'), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=en', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/recover/initiate/', params='', query='ars=facebook_login', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruCards.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Books', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45471_0_0_0_0_0_0_0&src=fid45471', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/password_forgotten.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=en-gb', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/r.php', params='', query='api_key=1178097535547895&app_id=1178097535547895&cancel_url=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3De2c6ccc1d5f6129259117c1089982d09%23_%3D_&next=https%3A%2F%2Fwww.facebook.com%2Fv2.10%2Fdialog%2Foauth%3Fclient_id%3D1178097535547895%26state%3De2c6ccc1d5f6129259117c1089982d09%26response_type%3Dcode%26sdk%3Dphp-sdk-5.6.1%26redirect_uri%3Dhttps%253A%252F%252Fwww.dmsguild.com%252Ffacebook%252Ffacebook_sign_up_action.php%26scope%3Demail%252Cpublic_profile%252Cuser_friends%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D4f63da34-c154-41c0-8c36-6ab06c0be130%26tp%3Dunspecified&locale=pt_BR&display=page', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruComics.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_100221_0_0_0_0_0_0&src=fid100221', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/sale.php', params='', query='&filters=0_0_0_0_0_45711&cPath=9730_9733', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=es', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/login.php', params='', query='skip_api_login=1&api_key=1178097535547895&kid_directed_site=0&app_id=1178097535547895&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.10%2Fdialog%2Foauth%3Fclient_id%3D1178097535547895%26state%3De2c6ccc1d5f6129259117c1089982d09%26response_type%3Dcode%26sdk%3Dphp-sdk-5.6.1%26redirect_uri%3Dhttps%253A%252F%252Fwww.dmsguild.com%252Ffacebook%252Ffacebook_sign_up_action.php%26scope%3Demail%252Cpublic_profile%252Cuser_friends%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D4f63da34-c154-41c0-8c36-6ab06c0be130%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3De2c6ccc1d5f6129259117c1089982d09%23_%3D_&display=page&locale=en_US&pl_dbl=0', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_100191_0_0_0_0_0_0&src=fid100191', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='filters=44827_0_0_0_0&src=fid44827', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruFiction.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Reference%20Decks', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=fil', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/reg/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_100084_0_0_0_0_0_0&src=fid100084', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='filters=0_2140_0_0_0&src=fid2140', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=fr', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/login/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_100023_0_0_0_0_0_0&src=fid100023', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='filters=0_2150_0_0_0&src=fid2150', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=hr', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/lite/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_45832_0_0_0_0_0_0&src=fid45832', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='filters=0_2200_0_0_0&src=fid2200', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=it', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/watch/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_45796_0_0_0_0_0_0&src=fid45796', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='filters=0_0_100_0_0&src=fid100', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=hu', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/places/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=0_45728_0_0_0_0_0_0&src=fid45728', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='filters=0_0_940_0_0&src=fid940', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='lang=nl', fragment=''), 1)
#   4%|███████▋                                                                                                                                                                                               | 1/26 [02:16<56:47, 136.30s/it]
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/games/', params='', query='', fragment=''), 1)
# 136.29879355430603 segundos = 2.271646559238434 minutos
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/', params='', query='', fragment=''), 0)
# A url 'https://www.mercadorpg.com.br/' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0xe9 in position 1008: invalid continuation byte
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/', params='', query='', fragment='MainContent'), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/hitpointpress', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.instagram.com', path='/hitpointpress/', params='', query='', fragment=''), 0)
# A url 'mailto:support@hitpointpress.com' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error unknown url type: mailto>
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/login.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/dms_guild', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/thedeckofmany', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/DungeonMastersGuild', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/my_library.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Books', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment='timeline'), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Reference%20Decks', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrucards.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=3a2de95cd21e04233eb58725ba051894&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_262/Gamma-World', params='', query='src=DnDClassicsButton', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/wishlist.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrucomics.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Digital', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/i/moments', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=88390837404984e7c6b4f265f054b3f6&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/shopping_cart.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrufiction.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Miniatures', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.wargamevault.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment='supported_languages'), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=466c0444bcb37c3742862e2c8832df9b&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.storytellersvault.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment='login_box'), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/shopping_cart.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Accessories', fragment=''), 1)
# A url 'https://support.dmsguild.com/hc/en-us/categories/1260801293870-Content-Creator-Questions' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# A url 'https://docs.google.com/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform?usp=pp_url&entry.1569704748=Dungeon Masters Guild' não foi coletada, a seguinte exceção foi lançada:
# <class 'http.client.InvalidURL'>: URL can't contain control characters. '/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform?usp=pp_url&entry.1569704748=Dungeon Masters Guild' (found at least ' ')
# A url 'https://support.drivethrurpg.com/hc/en-us/articles/209937123-About-DriveThruRPG' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# A url 'https://pbs.twimg.com/profile_images/1522629199089000452/AZ_Wqowk_400x400.png' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=id', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.pathfinderinfinite.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=12cb8e740bf809e9cb021ba1d86605be&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment='create_account_box'), 1)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Resources', fragment=''), 1)
# (ParseResult(scheme='https', netloc='t.co', path='/UMFsYDBWSm', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/index.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruRPG.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=msa', fragment=''), 1)
# A url 'https://pbs.twimg.com/profile_images/1522629199089000452/AZ_Wqowk.png' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/patreon', params='', query='', fragment=''), 0)
# (ParseResult(scheme='http', netloc='status.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/the-deck-of-many/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='t.co', path='/xMScEeoDR4', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=ca', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=28eee64de0c76f7e11dbb33fd341347a&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/password_forgotten.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/login.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruCards.com', fragment=''), 0)
# A url 'https://pbs.twimg.com/profile_images/1105646980498284544/RGWD0tJY_400x400.png' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# (ParseResult(scheme='https', netloc='t.co', path='/Va5XYxsuwO', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='business.twitter.com', path='/en/help/troubleshooting/how-twitter-ads-work.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/humblewood/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=cs', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=0d4e8f67692c0bf5e30110dae95d74ca&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/my_library.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruComics.com', fragment=''), 0)
# A url 'https://pbs.twimg.com/profile_images/1105646980498284544/RGWD0tJY.png' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/promo.php', params='', query='&filters=0_0_0_0_0_0_0_0_1000008', fragment=''), 1)
# (ParseResult(scheme='https', netloc='t.co', path='/QL0Ekxcbpp', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.twitter.com', path='/articles/20170514', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/big-bads/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=da', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/DriveThruRPG', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/wishlist.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruFiction.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45469_0_0_0_0_0_0_0&src=fid45469', fragment=''), 1)
# (ParseResult(scheme='https', netloc='business.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='t.co', path='/welq9jQsNy', params='', query='', fragment=''), 0)
# (ParseResult(scheme='http', netloc='support.twitter.com', path='/forums/26810/entries/78525', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/foolsgold/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=de', fragment=''), 1)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='/web/embedded-tweets', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=181736421874745&state=a212d3dd31368660b29947e2e4132c68&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.drivethrurpg.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment='login_box'), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45680_0_0_0_0_0_0_0&src=fid45680', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=Wargame Vault', fragment=''), 0)
# (ParseResult(scheme='https', netloc='t.co', path='/tEYx3luXvH', params='', query='', fragment=''), 0)
# (ParseResult(scheme='http', netloc='support.twitter.com', path='/articles/14226-how-to-find-your-twitter-short-code-or-long-code', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='business.twitter.com', path='/en/help/troubleshooting/how-twitter-ads-work.html', params='', query='', fragment='twtr-main'), 1)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/the-islands-of-sina-una/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=en', fragment=''), 1)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='/overview/terms/agreement', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=181736421874745&state=1c10f94eea7e96bdd66e0504058a35c7&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.drivethrurpg.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/browse.php', params='', query='filters=45470_0_0_0_0_0_0_0&src=fid45470', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment='create_account_box'), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=Storytellers Vault', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.twitter.com', path='/articles/118492-how-to-use-the-location-feature-on-mobile-devices', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/thegriffonssaddlebag/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=en-gb', fragment=''), 1)
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connection.py", line 175, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\util\connection.py", line 95, in create_connection
#     raise err
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\util\connection.py", line 85, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connectionpool.py", line 710, in urlopen
#     chunked=chunked,
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connectionpool.py", line 1040, in _validate_conn
#     conn.connect()
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connection.py", line 187, in _new_conn
#     self, "Failed to establish a new connection: %s" % e
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000221D91943C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\adapters.py", line 450, in send
#     timeout=timeout
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\connectionpool.py", line 786, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\urllib3\util\retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='bigbads.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000221D91943C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "G:\Meus Arquivos\Conhecimento\CEFET\Recuperação de Informação\cefet-ri-crawler-master\crawler\page_fetcher.py", line 62, in run
#     self.crawl_new_url()
#   File "G:\Meus Arquivos\Conhecimento\CEFET\Recuperação de Informação\cefet-ri-crawler-master\crawler\page_fetcher.py", line 51, in crawl_new_url
#     response = self.request_url(obj_url[0])
#   File "G:\Meus Arquivos\Conhecimento\CEFET\Recuperação de Informação\cefet-ri-crawler-master\crawler\page_fetcher.py", line 22, in request_url
#     response = requests.get(obj_url.geturl(), headers={'User-Agent': self.USER_AGENT})
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\sessions.py", line 667, in send
#     history = [resp for resp in gen]
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\sessions.py", line 667, in <listcomp>
#     history = [resp for resp in gen]
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\sessions.py", line 245, in resolve_redirects
#     **adapter_kwargs
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\Ramon\anaconda3\envs\ri\lib\site-packages\requests\adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='bigbads.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000221D91943C8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
#   8%|███████████████▎                                                                                                                                                                                       | 2/26 [04:16<50:42, 126.78s/it]
# 120.11700105667114 segundos = 2.0019500176111857 minutos
# A url 'https://www.mercadorpg.com.br/' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0xe9 in position 1008: invalid continuation byte
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/', params='', query='', fragment='MainContent'), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.instagram.com', path='/hitpointpress/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/hitpointpress', params='', query='', fragment=''), 0)
# A url 'mailto:support@hitpointpress.com' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error unknown url type: mailto>
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment='timeline'), 1)
# A url 'https://pbs.twimg.com/profile_images/1522629199089000452/AZ_Wqowk_400x400.png' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/thedeckofmany', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='http', netloc='status.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='t.co', path='/UMFsYDBWSm', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='business.twitter.com', path='/en/help/troubleshooting/how-twitter-ads-work.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/thedeckofmany', params='', query='', fragment='renderPageContentWrapper'), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/', params='', query='', fragment=''), 1)
# A url 'https://pbs.twimg.com/profile_images/1522629199089000452/AZ_Wqowk.png' não foi coletada, a seguinte exceção foi lançada:
# <class 'UnicodeDecodeError'>: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# (ParseResult(scheme='https', netloc='privacy.patreon.com', path='/policies', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='t.co', path='/xMScEeoDR4', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='/web/embedded-tweets', params='', query='', fragment=''), 0)
# A url 'tel:833-972-8766' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error unknown url type: tel>
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Books', fragment=''), 1)
# A url 'https://support.patreon.com/hc/en-us/' não foi coletada, a seguinte exceção foi lançada:
# <class 'urllib.error.URLError'>: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/patreon', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.instagram.com', path='/patreon', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.twitter.com', path='/articles/20170514', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/login.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='/overview/terms/agreement', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.twitter.com', path='/patreon', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/i/moments', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='t.co', path='/Va5XYxsuwO', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Reference%20Decks', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_9733/d20-Modern-Generic', params='', query='src=DnDC', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrucards.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/DungeonMastersGuild', params='', query='', fragment=''), 0)
# (ParseResult(scheme='http', netloc='support.twitter.com', path='/forums/26810/entries/78525', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='/overview/terms/policy', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/login', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/my_library.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='http', netloc='www.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/browse/pub/44/Wizards-of-the-Coast/subcategory/9730_262/Gamma-World', params='', query='src=DnDClassicsButton', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='', fragment='supported_languages'), 1)
# (ParseResult(scheme='https', netloc='t.co', path='/QL0Ekxcbpp', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Digital', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrucomics.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrufiction.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/create', params='', query='', fragment=''), 1)
# (ParseResult(scheme='http', netloc='support.twitter.com', path='/articles/14226-how-to-find-your-twitter-short-code-or-long-code', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.facebook.com', path='/v2.10/dialog/oauth', params='', query='client_id=1178097535547895&state=8d3c90628195a3e11bc31d47552c9b7b&response_type=code&sdk=php-sdk-5.6.1&redirect_uri=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php&scope=email%2Cpublic_profile%2Cuser_friends', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.twitter.com', path='/patreon', params='', query='', fragment='timeline'), 1)
# (ParseResult(scheme='https', netloc='twitter.com', path='/HitPointPress', params='', query='lang=id', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.dmsguild.com', path='/wishlist.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='t.co', path='/welq9jQsNy', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrurpg.com', path='/index.php', params='', query='src=sistersite', fragment=''), 0)
# ...
# (ParseResult(scheme='https', netloc='fr-fr.facebook.com', path='/login.php', params='', query='skip_api_login=1&api_key=1178097535547895&kid_directed_site=0&app_id=1178097535547895&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.10%2Fdialog%2Foauth%3Fclient_id%3D1178097535547895%26state%3D1871bd4f3609286c9b39682deb0d6cc6%26response_type%3Dcode%26sdk%3Dphp-sdk-5.6.1%26redirect_uri%3Dhttps%253A%252F%252Fwww.dmsguild.com%252Ffacebook%252Ffacebook_sign_up_action.php%26scope%3Demail%252Cpublic_profile%252Cuser_friends%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D10e9a2eb-beb7-4537-b8fb-b017832f7358%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3D1871bd4f3609286c9b39682deb0d6cc6%23_%3D_&display=page&locale=fr_FR&pl_dbl=0', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.google.com', path='/analytics/answer/181881', params='', query='hl=pt-BR', fragment=''), 0)
# (ParseResult(scheme='https', netloc='ja-jp.facebook.com', path='/login.php', params='', query='skip_api_login=1&api_key=1178097535547895&kid_directed_site=0&app_id=1178097535547895&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.10%2Fdialog%2Foauth%3Fclient_id%3D1178097535547895%26state%3D1871bd4f3609286c9b39682deb0d6cc6%26response_type%3Dcode%26sdk%3Dphp-sdk-5.6.1%26redirect_uri%3Dhttps%253A%252F%252Fwww.dmsguild.com%252Ffacebook%252Ffacebook_sign_up_action.php%26scope%3Demail%252Cpublic_profile%252Cuser_friends%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D10e9a2eb-beb7-4537-b8fb-b017832f7358%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3D1871bd4f3609286c9b39682deb0d6cc6%23_%3D_&display=page&locale=ja_JP&pl_dbl=0', fragment=''), 0)
# (ParseResult(scheme='https', netloc='ar-ar.facebook.com', path='/login.php', params='', query='skip_api_login=1&api_key=1178097535547895&kid_directed_site=0&app_id=1178097535547895&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.10%2Fdialog%2Foauth%3Fclient_id%3D1178097535547895%26state%3D1871bd4f3609286c9b39682deb0d6cc6%26response_type%3Dcode%26sdk%3Dphp-sdk-5.6.1%26redirect_uri%3Dhttps%253A%252F%252Fwww.dmsguild.com%252Ffacebook%252Ffacebook_sign_up_action.php%26scope%3Demail%252Cpublic_profile%252Cuser_friends%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D10e9a2eb-beb7-4537-b8fb-b017832f7358%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3D1871bd4f3609286c9b39682deb0d6cc6%23_%3D_&display=page&locale=ar_AR&pl_dbl=0', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.bulletin.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='twitter.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='safebrowsing.google.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='http', netloc='status.twitter.com', path='/pages/history/564314ae3309c22c3b0002fa', params='', query='', fragment=''), 1)
# (ParseResult(scheme='http', netloc='www.networkadvertising.org', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='privacy.google.com', path='/businesses/affiliates', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='privacy.linkedin.com', path='/regionalinfo', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='safety.google', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='about.linkedin.com', path='/transparency', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='accounts.google.com', path='/signup/v2/webcreateaccount', params='', query='biz=false&flowName=GlifWebSignIn&flowEntry=SignUp&hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='apps.google.com', path='/meet/', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='cards-dev.twitter.com', path='/validator', params='', query='', fragment='timeline'), 1)
# (ParseResult(scheme='https', netloc='about.google', path='/products/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='safety.linkedin.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='accounts.google.com', path='/AccountChooser', params='', query='continue=https://docs.google.com/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform?usp%3Dpp_url%26entry.1569704748%3DDriveThruComics.com&service=wise', fragment=''), 0)
# (ParseResult(scheme='https', netloc='assistant.google.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='transparencyreport.google.com', path='/user-data/overview', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='userresearch.google.com', path='/', params='', query='l=9&reserved=0&pType=andro&productTag=andr&campaignType=ghc&campaignDate=apr17&labelTag=0&referral_code=Wc85355', fragment=''), 0)
# (ParseResult(scheme='https', netloc='myactivity.google.com', path='/myactivity', params='', query='utm_source=pp&hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='dev.twitter.com', path='/overview/terms/agreement', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='blog.linkedin.com', path='/2017/february/3/introducing-the-linkedin-workforce-report', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.twitterflightschool.com', path='/sl/382652bc', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='transparencyreport.google.com', path='/safe-browsing/overview', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='security.googleblog.com', path='/2016/03/more-encryption-more-notifications-more.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='pay.facebook.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='l.facebook.com', path='/l.php', params='', query='u=https%3A%2F%2Fwww.instagram.com%2F&h=AT3Ol4vw79J89ciLipVMqnkcaBBn0UbnkWzgf3uMgDTd_4WFy0oNzC8rYFYt31b5aA4G6-M1ncTrQPbfIL6sgmqjP5u1x2EeMI3493zXpxptisiQFpERBulyYpxhxlkts5VzzQ1bT9cn8MDSzlYQyXnTif_BxQK5', fragment=''), 0)
# (ParseResult(scheme='https', netloc='support.twitter.com', path='/articles/20170514', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='de-de.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='gdpr.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='fr-fr.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='zh-cn.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='es-la.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='engineering.linkedin.com', path='/ab-testing/xlnt-platform-driving-ab-testing-linkedin', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hi-in.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='kids.youtube.com', path='/privacynotice', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.wargamevault.com', path='/shopping_cart.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='it-it.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='takeout.google.com', path='/', params='', query='utm_source=pp&hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='fiber.google.com', path='/legal/privacy.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='ja-jp.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='developer.twitter.com', path='/en/docs', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='business.twitter.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='fi.google.com', path='/about/tos/', params='', query='', fragment='project-fi-privacy-notice'), 0)
# (ParseResult(scheme='http', netloc='www.twitter.com', path='', params='', query='', fragment='timeline'), 1)
# (ParseResult(scheme='https', netloc='itunes.apple.com', path='/us/app/google-assistant/id1220976145', params='', query='mt=8', fragment=''), 0)
# (ParseResult(scheme='https', netloc='help.twitter.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='marketing.twitter.com', path='/en/insights', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='contacts.google.com', path='', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='status.twitterstat.us', path='/pages/history/564314ae3309c22c3b0002fa', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='cloud.google.com', path='/terms/cloud-privacy-notice', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='pt-br.facebook.com', path='/login.php', params='', query='skip_api_login=1&api_key=1178097535547895&kid_directed_site=0&app_id=1178097535547895&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.10%2Fdialog%2Foauth%3Fclient_id%3D1178097535547895%26state%3D1871bd4f3609286c9b39682deb0d6cc6%26response_type%3Dcode%26sdk%3Dphp-sdk-5.6.1%26redirect_uri%3Dhttps%253A%252F%252Fwww.dmsguild.com%252Ffacebook%252Ffacebook_sign_up_action.php%26scope%3Demail%252Cpublic_profile%252Cuser_friends%26ret%3Dlogin%26fbapp_pres%3D0%26logger_id%3D10e9a2eb-beb7-4537-b8fb-b017832f7358%26tp%3Dunspecified&cancel_url=https%3A%2F%2Fwww.dmsguild.com%2Ffacebook%2Ffacebook_sign_up_action.php%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%26state%3D1871bd4f3609286c9b39682deb0d6cc6%23_%3D_&display=page&locale=pt_BR&pl_dbl=0', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.google.com.br', path='/intl/en/about/products', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.twitter.com', path='/patreon', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='blog.twitter.com', path='/developer/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='about.twitter.com', path='/en/who-we-are/twitter-for-good.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='research.google.com', path='/teams/spa/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='ar-ar.facebook.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='docs.google.com', path='/forms/d/e/1FAIpQLSeWuv5ypRICEVxiOZ8wXda06E354X23IWFYhOc2P8qP7Hf26Q/viewform', params='', query='usp=pp_url&entry.1569704748=DriveThruFiction.com', fragment=''), 0)
# (ParseResult(scheme='https', netloc='developers.google.com', path='/safe-browsing/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='payments.google.com', path='/legaldocument', params='', query='family=0.privacynotice&hl=en', fragment=''), 0)
# (ParseResult(scheme='http', netloc='optout.aboutads.info', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.android.com', path='/security/overview/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.patreon.com', path='/', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='scholar.google.com', path='/intl/en-US/scholar/about.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='privacy.google.com', path='/', params='', query='', fragment=''), 1)(ParseResult(scheme='https', netloc='play.google.com', path='/store/apps/details', params='', query='id=com.google.android.apps.googleassistant&hl=en', fragment=''), 0)
#
# (ParseResult(scheme='https', netloc='about.google', path='/products/', params='', query='', fragment='page-content'), 1)
# (ParseResult(scheme='https', netloc='brand.linkedin.com', path='/policies', params='', query='trk=content_footer-brand-policy', fragment=''), 0)
# (ParseResult(scheme='http', netloc='m.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='hitpointpress.com', path='/categories/', params='', query='_bc_fsnf=1&Product++Category=Books', fragment=''), 1)
# (ParseResult(scheme='https', netloc='play.google.com', path='/store/apps/details', params='', query='id=com.google.android.contacts', fragment=''), 0)
# (ParseResult(scheme='https', netloc='myaccount.google.com', path='/', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.pathfinderinfinite.com', path='/login.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='http', netloc='myprivacy.twitter.com', path='', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.drivethrufiction.com', path='/index.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.drivethrucomics.com', path='/index.php', params='', query='', fragment=''), 1)
# (ParseResult(scheme='https', netloc='www.android.com', path='/intl/en_us/auto/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='about.facebook.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='edu.google.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.gmail.com', path='/intl/en_us/mail/help/about.html', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='gsuite.google.com', path='/products/chat/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='chrome.google.com', path='/webstore/category/apps', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='enterprise.google.com', path='/chrome/chrome-browser/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='cloud.google.com', path='/security/compliance', params='', query='hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='business.linkedin.com', path='/elevate', params='', query='', fragment=''), 0)
# (ParseResult(scheme='http', netloc='www.google.com', path='/settings/ads', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='messenger.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='account.google.com', path='/', params='', query='', fragment=''), 0)
# (ParseResult(scheme='https', netloc='artsandculture.google.com', path='/', params='', query='utm_medium=referral&utm_source=about.google', fragment=''), 0)
# (ParseResult(scheme='https', netloc='developers.facebook.com', path='/', params='', query='ref=pf', fragment=''), 0)
# (ParseResult(scheme='https', netloc='adssettings.google.com', path='/', params='', query='ref=privacy-policy&hl=en', fragment=''), 0)
# (ParseResult(scheme='https', netloc='www.google.co.in', path='/edu/expeditions/', params='', query='', fragment=''), 0)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [14:14<00:00, 32.88s/it]
# (ParseResult(scheme='https', netloc='store.google.com', path='/category/connected_home', params='', query='', fragment=''), 0)
# 18.708234548568726 segundos = 0.3118039091428121 minutos

# %% [markdown]
# ### Dataframe dos estudos

# %%
df = pd.DataFrame.from_dict(results)
df
# Out:
#     n_threads        time
# 0           1  136.298794
# 1           2  120.117001
# 2           3   82.171929
# 3           4   41.021311
# 4           5   31.346788
# 5           6   27.539152
# 6           7   28.081438
# 7           8   24.222182
# 8           9   22.338548
# 9          10   21.180080
# 10         11   23.435407
# 11         12   20.738250
# 12         13   21.971577
# 13         14   20.518183
# 14         15   18.180609
# 15         16   17.585186
# 16         17   21.278494
# 17         18   19.760931
# 18         19   20.302062
# 19         30   18.741308
# 20         40   16.953178
# 21         50   17.330141
# 22         60   16.495294
# 23         70   18.834018
# 24         80   29.603098
# 25         90   18.708235

# %%
df.to_parquet("results.parquet")

# %%
df = pd.read_parquet("results.parquet")

# %% [markdown]
# ### Máquina utilzada
# I9-9900K - 8 cores - 16 threads
#
# 24GB RAM DDR4

# %% [markdown]
# ## Gráfico do tempo em função do número de threads

# %%
plt.figure(figsize=(14, 9), dpi=100)
plot = sns.lineplot(data=df, x="n_threads", y="time", marker="o", color="tab:green")
plt.xlabel("Nº Threads")
plt.ylabel("Tempo")
plt.title("Tempo em função do número de threads")
plot.set_xticks(np.arange(0, 91, step=5))
plt.show()

# %% [markdown]
# ### Observações sobre o gráfico
# - Pode-se observar que a coleta com uma única thread é significativamente mais lenta que as outras coletas.
# - O tempo praticamente estabiliza depois de um certo número de threads (por volta de 16), que coincide com o número de threads do processador utilizado.
